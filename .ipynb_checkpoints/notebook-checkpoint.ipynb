# %% [markdown]
# Цель работы: разработать инструмент для обнаружения дефектов разрыва оксидного аморфного слоя, образовавшихся в результате приложения к образцам напряжения пробоя, а также их площади по электронно-микроскопическим изображениям с разным увеличением.

# %% [markdown]
# Задачи:
# - определение оптимального размера изображения (в пикселях) для обучения модели и предсказания
#     - использование полученной программы предпологает съемку крупного по площади изображения с определенным увеличением, нарезку его на части, получние предсказаний по каждой из них (попиксельно) и сборку предсказаний в изображение такого же размера как и исходное
# - разметка изображений (попиксельная классификация) и их аугментация
#     - какую долю от изображения должен занимать обнаруживаемый объект?
# - обучение моделей разной глубины, предлагается взять за основу сверточные модели глубиной 6 (2700 параметров) и 9 (3700000 параметров) слоев из проектов по распознаванию жестов и пчел, соответственно. Необходимо выбрать оптимальную модель по соотношению скорость работы - точность, т.к. планируется обрабатывать изображения большой площади
# - провести интерпретацию работы моделей (оценить результаты сверточных слоев по ядрам сверток, проверить выход после каждого слоя) для того чтобы определить какие участки дефектов являются наиболее важными для определения

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
im_700x = plt.imread('../images/raw_images/ETD_1_001_700x.tif')
print('700x magnification')
plt.imshow(im_700x, cmap='Greys_r')
plt.show()
print('Size:', im_700x.shape)
plt.imshow(im_700x[175:275, 1275:1375], cmap='Greys_r')
plt.show()
print('Size:', im_700x[175:275, 1275:1375].shape)
# Out:
# 700x magnification
# Size: (1094, 1536)
# Size: (100, 100)

# %%
im_1400x = plt.imread('../images/raw_images/ETD_1_002_1400x.tif')
print('1400x magnification')
plt.imshow(im_1400x, cmap='Greys_r')
plt.show()
print('Size:', im_1400x.shape)
plt.imshow(im_1400x[700:800, 1040:1140], cmap='Greys_r')
plt.show()
print('Size:', im_1400x[700:800, 1040:1140].shape)
# Out:
# 1400x magnification
# Size: (1094, 1536)
# Size: (100, 100)

# %%
im_2800x = plt.imread('../images/raw_images/ETD_2_006_2800x.tif')
print('2800x magnification')
plt.imshow(im_2800x, cmap='Greys_r')
plt.show()
print('Size:', im_2800x.shape)
plt.imshow(im_2800x[450:550, 730:830], cmap='Greys_r')
plt.show()
print('Size:', im_2800x[450:550, 730:830].shape)
# Out:
# 2800x magnification
# Size: (1094, 1536)
# Size: (100, 100)

# %%
im_6900x = plt.imread('../images/raw_images/ETD_1_004_6900x.tif')
print('6900x magnification')
plt.imshow(im_6900x, cmap='Greys_r')
plt.show()
print('Size:', im_6900x.shape)
plt.imshow(im_6900x[350:750, 550:950], cmap='Greys_r')
plt.show()
print('Size:', im_6900x[350:750, 550:950].shape)
# Out:
# 6900x magnification
# Size: (1094, 1536)
# Size: (400, 400)

# %% [markdown]
# Можно сжать в 4 раза

# %%
im_13800x = plt.imread('../images/raw_images/ETD_3_008_13800x.tif')
print('13800x magnification')
plt.imshow(im_13800x, cmap='Greys_r')
plt.show()
print('Size:', im_13800x.shape)
plt.imshow(im_13800x[420:820, 450:850], cmap='Greys_r')
plt.show()
print('Size:', im_13800x[420:820, 450:850].shape)
# Out:
# 13800x magnification
# Size: (1094, 1536)
# Size: (400, 400)

# %% [markdown]
# Создадим функцию для сжатия изображений скользящим окном.

# %%
def compression(array, coef):

    new_list = [0] * (array.shape[1] // coef)
    for i in range(array.shape[0] // coef):
        new_list[i] = []
        for j in range(array.shape[1] // coef):
            compression = round(array[i*coef:i*coef+coef, j*coef:j*coef+coef].mean())
            new_list[i].append(int(compression))
    return np.array(new_list)

# %%
plt.imshow(compression(im_13800x[420:820, 450:850], 4), cmap='Greys_r')
plt.show()
print('Size after compression', compression(im_13800x[420:820, 450:850], 4).shape)
# Out:
# Size after compression (100, 100)

# %% [markdown]
# Окно размером 100х100 пикселей на первый взгляд выглядит оптимальным.
